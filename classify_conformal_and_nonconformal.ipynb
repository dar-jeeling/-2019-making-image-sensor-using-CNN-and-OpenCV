# %%
from PIL import Image
import os, glob, sys, numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import np_utils

img_dir = './semi_draw_img/nin'
categories = ['concopy', 'unconcopy']
np_classes = len(categories)

image_w = 64
image_h = 64


pixel = image_h * image_w * 3

X = []
y = []

for idx, conformal in enumerate(categories):
    img_dir_detail = img_dir + "/" + conformal
    files = glob.glob(img_dir_detail+"/*.*")


    for i, f in enumerate(files):
        try:
            img = Image.open(f)
            img = img.convert("RGB")
            img = img.resize((image_w, image_h))
            data = np.asarray(img)
            #Y는 0 아니면 1이니까 idx값으로 넣는다.
            X.append(data)
            y.append(idx)
            if i % 300 == 0:
                print(conformal, " : ", f)
        except:
            print(conformal, str(i)+" 번째에서 에러 ")
X = np.array(X)
Y = np.array(y)


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1)

xy = (X_train, X_test, Y_train, Y_test)
np.save("./numpy_data/drawtest5.npy", xy)
# Out:
# concopy  :  ./semi_draw_img/nin/concopy\com12_0_1233.png
# concopy  :  ./semi_draw_img/nin/concopy\com1_0_9377.png
# unconcopy  :  ./semi_draw_img/nin/unconcopy\uncom16_0_1233.png
# unconcopy  :  ./semi_draw_img/nin/unconcopy\uncom2_0_9377.png

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend.tensorflow_backend as K

X_train, X_test, y_train, y_test = np.load('./numpy_data/drawtest5.npy')

print(X_train.shape)
print(X_train.shape[0])
print(np.bincount(y_train))
print(np.bincount(y_test))
# Out:
# (596, 64, 64, 3)
# 596
# [320 276]
# [37 30]

# %%
image_w = 64
image_h = 64
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255


with K.tf_ops.device('/device:GPU:0'):
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(32, (3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation="sigmoid"))
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    model_dir = './model'
    if not os.path.exists(model_dir):
        os.mkdir(model_dir)
    model_path = model_dir + "/uncon_con_classify.model"
    
    checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_loss', patience=7)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 328,225
# Trainable params: 328,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_split=0.15, callbacks=[checkpoint, early_stopping])
# Out:
# Train on 506 samples, validate on 90 samples
# Epoch 1/100
# 506/506 [==============================] - 3s 6ms/step - loss: 0.6734 - accuracy: 0.5949 - val_loss: 0.5719 - val_accuracy: 0.8889
#
# Epoch 00001: val_loss improved from inf to 0.57190, saving model to ./model/uncon_con_classify.model
# Epoch 2/100
# 506/506 [==============================] - 3s 5ms/step - loss: 0.5356 - accuracy: 0.7925 - val_loss: 0.3797 - val_accuracy: 0.9000
#
# Epoch 00002: val_loss improved from 0.57190 to 0.37970, saving model to ./model/uncon_con_classify.model
# Epoch 3/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.4314 - accuracy: 0.8162 - val_loss: 0.3410 - val_accuracy: 0.8889
#
# Epoch 00003: val_loss improved from 0.37970 to 0.34103, saving model to ./model/uncon_con_classify.model
# Epoch 4/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.4065 - accuracy: 0.8360 - val_loss: 0.3195 - val_accuracy: 0.8889
#
# Epoch 00004: val_loss improved from 0.34103 to 0.31946, saving model to ./model/uncon_con_classify.model
# Epoch 5/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.3381 - accuracy: 0.8775 - val_loss: 0.2765 - val_accuracy: 0.9000
#
# Epoch 00005: val_loss improved from 0.31946 to 0.27649, saving model to ./model/uncon_con_classify.model
# Epoch 6/100
# 506/506 [==============================] - 3s 5ms/step - loss: 0.3021 - accuracy: 0.8854 - val_loss: 0.2652 - val_accuracy: 0.9000
#
# Epoch 00006: val_loss improved from 0.27649 to 0.26516, saving model to ./model/uncon_con_classify.model
# Epoch 7/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.2689 - accuracy: 0.8992 - val_loss: 0.2128 - val_accuracy: 0.9000
#
# Epoch 00007: val_loss improved from 0.26516 to 0.21280, saving model to ./model/uncon_con_classify.model
# Epoch 8/100
# 506/506 [==============================] - 3s 5ms/step - loss: 0.2202 - accuracy: 0.9071 - val_loss: 0.2018 - val_accuracy: 0.9111
#
# Epoch 00008: val_loss improved from 0.21280 to 0.20181, saving model to ./model/uncon_con_classify.model
# Epoch 9/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.1821 - accuracy: 0.9091 - val_loss: 0.1266 - val_accuracy: 0.9333
#
# Epoch 00009: val_loss improved from 0.20181 to 0.12663, saving model to ./model/uncon_con_classify.model
# Epoch 10/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.1409 - accuracy: 0.9289 - val_loss: 0.1079 - val_accuracy: 0.9556
#
# Epoch 00010: val_loss improved from 0.12663 to 0.10786, saving model to ./model/uncon_con_classify.model
# Epoch 11/100
# 506/506 [==============================] - 3s 5ms/step - loss: 0.1055 - accuracy: 0.9585 - val_loss: 0.0757 - val_accuracy: 0.9667
#
# Epoch 00011: val_loss improved from 0.10786 to 0.07566, saving model to ./model/uncon_con_classify.model
# Epoch 12/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0690 - accuracy: 0.9723 - val_loss: 0.0676 - val_accuracy: 0.9667
#
# Epoch 00012: val_loss improved from 0.07566 to 0.06757, saving model to ./model/uncon_con_classify.model
# Epoch 13/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0754 - accuracy: 0.9704 - val_loss: 0.1042 - val_accuracy: 0.9667
#
# Epoch 00013: val_loss did not improve from 0.06757
# Epoch 14/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0482 - accuracy: 0.9842 - val_loss: 0.0231 - val_accuracy: 0.9889
#
# Epoch 00014: val_loss improved from 0.06757 to 0.02314, saving model to ./model/uncon_con_classify.model
# Epoch 15/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0440 - accuracy: 0.9822 - val_loss: 0.0285 - val_accuracy: 0.9889
#
# Epoch 00015: val_loss did not improve from 0.02314
# Epoch 16/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0380 - accuracy: 0.9881 - val_loss: 0.0612 - val_accuracy: 0.9556
#
# Epoch 00016: val_loss did not improve from 0.02314
# Epoch 17/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0473 - accuracy: 0.9802 - val_loss: 0.0765 - val_accuracy: 0.9778
#
# Epoch 00017: val_loss did not improve from 0.02314
# Epoch 18/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0440 - accuracy: 0.9842 - val_loss: 0.0105 - val_accuracy: 1.0000
#
# Epoch 00018: val_loss improved from 0.02314 to 0.01053, saving model to ./model/uncon_con_classify.model
# Epoch 19/100
# 506/506 [==============================] - 3s 5ms/step - loss: 0.0318 - accuracy: 0.9901 - val_loss: 0.0160 - val_accuracy: 0.9889
#
# Epoch 00019: val_loss did not improve from 0.01053
# Epoch 20/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0198 - accuracy: 0.9901 - val_loss: 0.0277 - val_accuracy: 0.9889
#
# Epoch 00020: val_loss did not improve from 0.01053
# Epoch 21/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0167 - accuracy: 0.9960 - val_loss: 0.0041 - val_accuracy: 1.0000
#
# Epoch 00021: val_loss improved from 0.01053 to 0.00408, saving model to ./model/uncon_con_classify.model
# Epoch 22/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0181 - accuracy: 0.9960 - val_loss: 0.0464 - val_accuracy: 0.9778
#
# Epoch 00022: val_loss did not improve from 0.00408
# Epoch 23/100
# 506/506 [==============================] - 3s 5ms/step - loss: 0.0094 - accuracy: 0.9980 - val_loss: 0.0097 - val_accuracy: 1.0000
#
# Epoch 00023: val_loss did not improve from 0.00408
# Epoch 24/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.0139 - val_accuracy: 1.0000
#
# Epoch 00024: val_loss did not improve from 0.00408
# Epoch 25/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
#
# Epoch 00025: val_loss improved from 0.00408 to 0.00324, saving model to ./model/uncon_con_classify.model
# Epoch 26/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0096 - accuracy: 0.9960 - val_loss: 0.0581 - val_accuracy: 0.9778
#
# Epoch 00026: val_loss did not improve from 0.00324
# Epoch 27/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0408 - val_accuracy: 0.9889
#
# Epoch 00027: val_loss did not improve from 0.00324
# Epoch 28/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0144 - accuracy: 0.9960 - val_loss: 0.0130 - val_accuracy: 1.0000
#
# Epoch 00028: val_loss did not improve from 0.00324
# Epoch 29/100
# 506/506 [==============================] - 3s 5ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.0051 - val_accuracy: 1.0000
#
# Epoch 00029: val_loss did not improve from 0.00324
# Epoch 30/100
# 506/506 [==============================] - 3s 5ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
#
# Epoch 00030: val_loss improved from 0.00324 to 0.00267, saving model to ./model/uncon_con_classify.model
# Epoch 31/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
#
# Epoch 00031: val_loss improved from 0.00267 to 0.00198, saving model to ./model/uncon_con_classify.model
# Epoch 32/100
# 506/506 [==============================] - 3s 5ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
#
# Epoch 00032: val_loss improved from 0.00198 to 0.00164, saving model to ./model/uncon_con_classify.model
# Epoch 33/100
# 506/506 [==============================] - 3s 5ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0098 - val_accuracy: 0.9889
#
# Epoch 00033: val_loss did not improve from 0.00164
# Epoch 34/100
# 506/506 [==============================] - 2s 5ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
#
# Epoch 00034: val_loss did not improve from 0.00164
# Epoch 35/100
# 506/506 [==============================] - 2s 5ms/step - loss: 8.1754e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
#
# Epoch 00035: val_loss did not improve from 0.00164
# Epoch 36/100
# 506/506 [==============================] - 2s 5ms/step - loss: 6.3087e-04 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
#
# Epoch 00036: val_loss did not improve from 0.00164
# Epoch 37/100
# 506/506 [==============================] - 2s 5ms/step - loss: 5.1237e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
#
# Epoch 00037: val_loss did not improve from 0.00164
# Epoch 38/100
# 506/506 [==============================] - 2s 5ms/step - loss: 4.6986e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
#
# Epoch 00038: val_loss did not improve from 0.00164
# Epoch 39/100
# 506/506 [==============================] - 3s 5ms/step - loss: 5.1463e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
#
# Epoch 00039: val_loss did not improve from 0.00164

# %%
print("정확도 : %.3f " %(model.evaluate(X_test, y_test)[1]))
# Out:
# 67/67 [==============================] - 0s 2ms/step
# 정확도 : 1.000

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'acc', 'val_acc'], loc='upper left')

fig = plt.gcf()
plt.show()
fig.savefig('modelloss.png')

# %%
from PIL import Image
import os, glob, numpy as np
from keras.models import load_model

import tensorflow as tf

seed = 5
tf.set_random_seed(seed)
np.random.seed(seed)

caltech_dir = './testcon/imgtest'


image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
filenames = []
files = glob.glob(caltech_dir+"/*/*.*")

for i, f in enumerate(files):
    img = Image.open(f)
    img = img.convert("RGB")
    img = img.resize((image_w, image_h))
    data = np.asarray(img)

    filenames.append(f)
    X.append(data)

X = np.array(X)
X = X.astype(float) / 255

model = load_model('./model/uncon_con_classify.model')
prediction = model.predict(X)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
cnt = 0

for i in prediction:
    if i >= 0.5: print("해당 " + filenames[cnt].split("\\")[1] + filenames[cnt].split("\\")[2] + "  이미지는 unconformal 로 추정됩니다.")
    else : print("해당 " + filenames[cnt].split("\\")[1] + filenames[cnt].split("\\")[2] + "  이미지는 conformal 으로 추정됩니다.")
    cnt += 1
# Out:
# 해당 newtestnewcon.1.PNG  이미지는 conformal 으로 추정됩니다.
# 해당 newtestnewcon.PNG  이미지는 conformal 으로 추정됩니다.
# 해당 newtestnewuncon.0.PNG  이미지는 conformal 으로 추정됩니다.
# 해당 newtestnewuncon.1.PNG  이미지는 unconformal 로 추정됩니다.
# 해당 newtestnewuncon.2.PNG  이미지는 unconformal 로 추정됩니다.
# 해당 ttestcom.0.PNG  이미지는 conformal 으로 추정됩니다.
# 해당 ttestcom.1.PNG  이미지는 conformal 으로 추정됩니다.
# 해당 ttestcom.2.PNG  이미지는 conformal 으로 추정됩니다.
# 해당 ttestcom.3.PNG  이미지는 conformal 으로 추정됩니다.
# 해당 ttestcom.4.PNG  이미지는 conformal 으로 추정됩니다.
# 해당 ttestcom.5.PNG  이미지는 conformal 으로 추정됩니다.
# 해당 ttestcom.6.PNG  이미지는 conformal 으로 추정됩니다.
# 해당 ttestuncom.0.jpg  이미지는 unconformal 로 추정됩니다.
# 해당 ttestuncom.1.PNG  이미지는 unconformal 로 추정됩니다.
# 해당 ttestuncom.2.PNG  이미지는 unconformal 로 추정됩니다.
# 해당 ttestuncom.3.PNG  이미지는 unconformal 로 추정됩니다.
# 해당 ttestuncom.4.PNG  이미지는 unconformal 로 추정됩니다.
# 해당 ttestuncom.5.gif  이미지는 unconformal 로 추정됩니다.
